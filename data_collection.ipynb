# %%
# !pip install spotipy --upgrade
# !pip install pymysql
# !pip install pandas
# !pip install mysqlclient
# Out:
# Requirement already up-to-date: spotipy in /Applications/anaconda3/lib/python3.7/site-packages (2.11.2)
# ...

# %%
import sys
import spotipy
import spotipy.util as util
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from sqlalchemy import create_engine
import pandas as pd
import json

# %%
cid = '4c22b87c455a4b3d8de0ec7a632e376f'
secret = '6370b94f7e5b4cd7a3f84c49fe2befa5'
redirect_uri = 'https://localhost:8888/callback'
scope = 'user-read-playback-position'

# %%
username='lindseyfry4'
token = util.prompt_for_user_token(username, scope, client_id=cid, client_secret=secret, 
                                       redirect_uri=redirect_uri)
sp = spotipy.Spotify(auth=token)
tracks = ['spotify:track:3ZiuxcBeRanTjfHzVBuuQe', 'spotify:track:6eOc29YX6IoRO2gwPoUjAs', 'spotify:track:6BBfG9FiwJhRVMCd9IYl6c', 'spotify:track:2PoqubfYq2Cl0nUyrrTht6', 'spotify:track:1pjqPytpUL6Yj98JESbQP9', 'spotify:track:4gmhssXAiRNfSlaeC2uHcL', 'spotify:track:0070lcYeexRMKyj7sa8J9f', 'spotify:track:5Xm9Ot36RbHOYBzi5S23I3',
         'spotify:track:7u33r4FRXE6oBnxFMhC6ex', 'spotify:track:1yQTCLbLfrmDtEMI2NnWMD', 'spotify:track:4JzOyYO61Yjb5eqYZsBaZy', 'spotify:track:4vXiLpBSieBAi4t7B6rjrN', 'spotify:track:1vMBf1HdwyWbxayA1KV6tt', 'spotify:track:0SA903LGHxe4ExdRY2SqVH', 'spotify:track:4dDZOtuazLyJnyKBQhggqL', 'spotify:track:19csz9Q9c4X2AGSJ1Bg5Wl'
         'spotify:track:5DWuE2zvXnbCBiBo3ohilB', 'spotify:track:7qoFhSKDXCgWeSiwOxOnS6', 'spotify:track:0UeQDqXRpWVRdF8JQhH0kv', 'spotify:track:4Rnel0cmjX9BkWf4tUfvzd', 'spotify:track:7nZ6lBIjTwgYmWavZkACoz', 'spotify:track:4uJPEwWfJQzEdHmPaw8cWC', 'spotify:track:0bPSRn4crnh5f1JhELPlyL', 'spotify:track:3eGsNpXzcb1BDkfSJI54NY'
          'spotify:track:1RsALParpm2YmjO9E3jc5L', 'spotify:track:26ky3sBMKv31Kpvil5pGDh', 'spotify:track:0UEkbY97YIi9tDlGnZf8lo', 'spotify:track:13SMscLTdjTPbQk62F7XIu', 'spotify:track:5J7zqPpQkN9JZiaELHNKSL', 'spotify:track:1otMErM5Sa5XrfIsVRKkbD', 'spotify:track:7yFpD5HEsWAnwpTsOgcJBL', 'spotify:track:0vYJLwPWCcN0dm6A5a2W00']
songs = sp.tracks(tracks)
songs
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21TinSsF5ytwsfdyz5VSVS'},
#       'href': 'https://api.spotify.com/v1/artists/21TinSsF5ytwsfdyz5VSVS',
#       'id': '21TinSsF5ytwsfdyz5VSVS',
#       'name': 'dodie',
#       'type': 'artist',
#       'uri': 'spotify:artist:21TinSsF5ytwsfdyz5VSVS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
# ...

# %%
playlist = songs['tracks']

# %%
playlist
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21TinSsF5ytwsfdyz5VSVS'},
#      'href': 'https://api.spotify.com/v1/artists/21TinSsF5ytwsfdyz5VSVS',
#      'id': '21TinSsF5ytwsfdyz5VSVS',
#      'name': 'dodie',
#      'type': 'artist',
#      'uri': 'spotify:artist:21TinSsF5ytwsfdyz5VSVS'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
# ...

# %%
type(playlist)
# Out:
# list

# %%
song_data = {
    'name':[],
    'id':[],
    'album_type':[],
    'name':[],
    'track_number':[],
    'duration_ms':[],
    'explicit':[],
    'popularity':[],
}
for track in playlist:
    name = track['name']
    song_data['name'].append(name)
    print(name)
    
    id = track['id']
    song_data['id'].append(id)
    print(id)
 
    album_type = track['album']['album_type']
    song_data['album_type'].append(album_type)
    print(album_type)
    
    name = track['album']['name']
    song_data['name'].append(name)
    print(name)
    
    track_number = track['track_number']
    song_data['track_number'].append(track_number)
    print(track_number)
    
    duration_ms = track['duration_ms']
    song_data['duration_ms'].append(duration_ms)
    print(duration_ms)
    
    explicit = track['explicit']
    song_data['explicit'].append(explicit)
    print(explicit)
    
    popularity = track['popularity']
    song_data['popularity'].append(popularity)
    print(popularity)
    
    print('*************************************')
# Out:
# Would You Be So Kind
# 3ZiuxcBeRanTjfHzVBuuQe
# single
# You - EP
# 6
# 180952
# False
# 66
# *************************************
# Marietta
# 6eOc29YX6IoRO2gwPoUjAs
# album
# Healing
# 10
# 237812
# False
# 37
# *************************************
# In The Middle
# 6BBfG9FiwJhRVMCd9IYl6c
# single
# You - EP
# 1
# 181632
# False
# 58
# *************************************
# Swimming In The Moonlight
# 2PoqubfYq2Cl0nUyrrTht6
# album
# Disappear Here
# 7
# 221280
# False
# 54
# *************************************
# The Feeling
# 1pjqPytpUL6Yj98JESbQP9
# single
# The Good Life
# 1
# 236213
# False
# 6
# *************************************
# Talk It Up
# 4gmhssXAiRNfSlaeC2uHcL
# single
# The Good Life
# 4
# 238480
# False
# 5
# *************************************
# Denim Jacket
# 0070lcYeexRMKyj7sa8J9f
# single
# Denim Jacket
# 1
# 247518
# False
# 2
# *************************************
# Hello Beautiful
# 5Xm9Ot36RbHOYBzi5S23I3
# single
# Hello Beautiful
# 1
# 147982
# ...

# %%
song_data
# Out:
# {'name': ['Would You Be So Kind',
#   'You - EP',
#   'Marietta',
#   'Healing',
#   'In The Middle',
#   'You - EP',
#   'Swimming In The Moonlight',
#   'Disappear Here',
#   'The Feeling',
#   'The Good Life',
#   'Talk It Up',
#   'The Good Life',
#   'Denim Jacket',
#   'Denim Jacket',
#   'Hello Beautiful',
#   'Hello Beautiful',
#   'Healing',
#   'Healing',
#   'The Record Player Song',
#   'The Record Player Song',
#   'Better Than Love',
#   'A Belle to Remember',
#   'Astronaut Kids',
#   'Astronaut Kids',
#   'You and I',
#   'You and I',
#   'Killer Queen',
#   'Killer Queen',
#   'Bad Enough For You',
#   'Dirty Work',
#   "I'm Me",
#   'Public Record',
#   'Between My Teeth',
#   'Between My Teeth',
#   'Sad in the Summer',
#   'Sad in the Summer',
#   'Kissaphobic',
#   'Visions of Hollywood',
#   'Black Coffee Morning',
#   'Black Coffee Morning',
#   'Perfect Too',
#   'Perfect Too',
#   'I Know A Place',
#   'About U',
#   'Celebrate The Reckless',
# ...

# %%
df = pd.DataFrame.from_dict(song_data, orient='index')
df.transpose()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-76f6f0451759> in <module>
# ----> 1 df = pd.DataFrame.from_dict(song_data)
#       2 df.transpose()
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1245             raise ValueError("only recognize index or columns for orient")
#    1246
# -> 1247         return cls(data, index=index, columns=columns, dtype=dtype)
#    1248
#    1249     def to_numpy(self, dtype=None, copy=False) -> np.ndarray:
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
# ...

# %%
df.head(5)
# Out:
#                                   0                       1   \
# name            Would You Be So Kind                You - EP
# id            3ZiuxcBeRanTjfHzVBuuQe  6eOc29YX6IoRO2gwPoUjAs
# album_type                    single                   album
# track_number                       6                      10
# duration_ms                   180952                  237812
#
#                                   2                       3   \
# name                        Marietta                 Healing
# id            6BBfG9FiwJhRVMCd9IYl6c  2PoqubfYq2Cl0nUyrrTht6
# album_type                    single                   album
# track_number                       1                       7
# duration_ms                   181632                  221280
#
#                                   4                       5   \
# name                   In The Middle                You - EP
# id            1pjqPytpUL6Yj98JESbQP9  4gmhssXAiRNfSlaeC2uHcL
# ...

# %%
df.head(5)

# %%
engine = create_engine('mysql+mysqldb://lindseyf_dba:sql_2020@lindseyfry.lmu.build/lindseyf_mySpotify?charset=utf8')

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# /Applications/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# ...
