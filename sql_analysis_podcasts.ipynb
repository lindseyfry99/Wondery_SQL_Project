# %%
# %load_ext sql

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE
# Out:
# 'Connected: admin@podcast_shows'

# %% [markdown]
# ### Exploratory Query #1
# The purpose of this query is to find the number of Wondery shows in the podcast database.
# I want to understand the range of categories for the Wondery company.

# %%
# %%sql
# SELECT title, author, category
# FROM `podcast shows`
# WHERE author LIKE '%Wondery%';
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 12 rows affected.
# [('FOUND', 'FoundMusical/Killer/Wondery', 'Society & Culture'),
#  ('Juicy Scoop with Heather McDonald', 'Heather McDonald / Wondery', 'Comedy'),
#  ('Mad About Movies', 'Kent Garrison, Richard Bardon, Brian Gill / Wondery', 'TV & Film'),
#  ('Radio Drama Revival', 'Radio Drama Revival / Wondery', 'Arts'),
#  ('Real Crime Profile', 'Real Crime Profile / Wondery', 'Society & Culture'),
#  ('Reality Life with Kate Casey', 'Kate Casey / Wondery', 'Comedy'),
#  ('Secrets, Crimes & Audiotape', 'Wondery', 'Arts'),
#  ("Stories Podcast - A Free Children's Story Podcast for Bedtime, Car Rides, and Kids of All Ages!", 'Stories Podcast / Wondery', 'Kids & Family'),
#  ('Sword and Scale', 'True Crime Media | Incongruity | Wondery', 'Science & Medicine'),
#  ('The Cleansed: A Post-Apocalyptic Saga', 'FinalRune Productions / Wondery', 'Arts'),
#  ('The Vanished Podcast', 'The Vanished Podcast / Wondery', 'Society & Culture'),
#  ('Tumble Science Podcast for Kids', 'Tumble Media / Wondery', 'Kids & Family')]

# %%
# %%sql
# SELECT COUNT(DISTINCT category) AS unique_category_count
# FROM `podcast shows`
# WHERE author LIKE '%Wondery%';
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 1 rows affected.
# [(6,)]

# %% [markdown]
# ### Exploratory Query #1
# Discovery: I discovered that the Wondery company has 12 different podcasts with a wide range of categories. They have podcasts in 6 different categories which include Society&Culture, Comedy, TV&Film, Arts, Kids&Family, and Science&Medicine.

# %% [markdown]
# ### Exploratory Query #2
# Purpose: The `podcast shows` database is the largest and has the most room for null or incorrect values. I want to get a count of null values in the link, subtitle, description and summary columns to determine whether or not they are valuable enough to keep.

# %%
# %%sql
# SELECT SUM(CASE WHEN link IS NULL THEN 1 ELSE 0 END) AS link_null_count,
#         SUM(CASE WHEN subtitle IS NULL THEN 1 ELSE 0 END) AS subtitle_null_count,
#         SUM(CASE WHEN description IS NULL THEN 1 ELSE 0 END) AS description_null_count,
#         SUM(CASE WHEN summary IS NULL THEN 1 ELSE 0 END) AS summary_null_count
# FROM `podcast shows`;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# (MySQLdb._exceptions.OperationalError) (1054, "Unknown column 'link' in 'field list'")
# [SQL: SELECT SUM(CASE WHEN link IS NULL THEN 1 ELSE 0 END) AS link_null_count,
#         SUM(CASE WHEN subtitle IS NULL THEN 1 ELSE 0 END) AS subtitle_null_count,
#         SUM(CASE WHEN description IS NULL THEN 1 ELSE 0 END) AS description_null_count,
#         SUM(CASE WHEN summary IS NULL THEN 1 ELSE 0 END) AS summary_null_count
# FROM `podcast shows`;]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
# SELECT SUM(CASE WHEN description IS NULL THEN 1 ELSE 0 END) AS description_null_count
# FROM `podcast shows`;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 1 rows affected.
# [(Decimal('2715'),)]

# %% [markdown]
# ### Exploratory Query #2
# Discovery: From this query, I found that I should keep description because it has the fewest null values and provides valuable information. I will delete the link, subtitle, and summary columns because they do not provide enough valuable information and have many null values. Due to the fact that I deleted the link, subtitle, and summary columns, the first query will appear as an error. I have shown the working logic with the description column which I did not delete.

# %% [markdown]
# ### Business Question #1
# Question: Who listens to podcasts and what types of genres do they like to listen to?
#
# Business Justification: This query helps the Wondery understand which users from which countries are actively using their accounts and listening to podcasts. It shows the business which genres of shows are most commonly listened to based on the preferences of each country. This will help them understand how to market to each country and what content to make based on the content they already provide.
#
# SQL Features Used: JOIN, CONCAT, CASE, ORDER BY

# %%
# %%sql
# SELECT CONCAT(pl.first_name, ' ', pl.last_name) AS listener_name, pl.country, pl.zip_code, ps.title AS podcast_title, ps.category AS genre,
#             CASE
#                 WHEN pl.user_activity = 0 THEN 'Active'
#                 WHEN pl.user_activity = 1 THEN 'Inactive'
#             END AS listener_status
# FROM `podcast shows` ps
# JOIN `podcast listeners` pl
#     ON ps.id = pl.id
# ORDER BY pl.country, ps.category;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 239 rows affected.
# [('Wynter Delgado', 'American Samoa', 11604, 'The Michelli Experience', 'Business', 'Inactive'),
#  ('Wynter Delgado', 'American Samoa', 11604, 'Fin de Semana', 'Sports', 'Active'),
#  ('Wynter Delgado', 'American Samoa', 11604, 'Endurance Corner Radio', 'Sports & Recreation', 'Active'),
#  ('Zelda Mckinney', 'Andorra', 39031, 'Forex Daily Podcast', 'Business', 'Active'),
#  ('Zelda Mckinney', 'Andorra', 39031, 'IGN Games Podcasts', 'Games & Hobbies/Video Games', 'Inactive'),
#  ('Graham Levine', 'Andorra', 46394, "BSA's ScoutCast", 'Government & Organizations/Non-Profit', 'Active'),
#  ('Graham Levine', 'Andorra', 46394, 'Pulpit Power Podcast', 'Religion & Spirituality', 'Active'),
#  ('Zelda Mckinney', 'Andorra', 39001, 'BBC Inside Science', 'Science & Medicine', 'Active'),
#  ('Graham Levine', 'Andorra', 46394, "Fraser's Affiliate Marketing Blog ¬ª Podcasts", 'Society & Culture', 'Active'),
#  ('Veronica Beach', 'Angola', 14704, 'Board Games with Scott', 'Games & Hobbies/Other Games', 'Active'),
#  ('Cyrus Reynolds', 'Antigua and Barbuda', 96966, 'Triathlon Training Tips', 'Games & Hobbies', 'Active'),
#  ('Cyrus Reynolds', 'Antigua and Barbuda', 96966, 'Amazing Facts Presents Video', 'Religion & Spirituality/Christianity', 'Active'),
#  ('Christen Stark', 'Austria', 76507, 'Internet Business Mastery | Escape the 9-to-5. Make More Money. Start an Internet Business, Now!', 'Business', 'Active'),
#  ('Christen Stark', 'Austria', 76507, 'TheBlackSphere Radio Show', 'Politics Conservative', 'Active'),
#  ('Christen Stark', 'Austria', 76507, 'Geek Out With Your Tech Out', 'Technology/Tech News', 'Active'),
#  ('Laurel Yates', 'Bahamas', 45812, 'Today in Board Games Week in Review - Board game news, gamer trends, new game releases, Kickstarter games', 'Games & Hobbies/Other Games', 'Active'),
#  ('Laurel Yates', 'Bahamas', 45812, 'Interpreter Magazine', 'News & Politics', 'Active'),
#  ('Laurel Yates', 'Bahamas', 45812, "Bill O'Reilly", 'News & Politics', 'Active'),
#  ('Samson Bray', 'Bahrain', 18223, '', '', 'Active'),
#  ('Samson Bray', 'Bahrain', 18223, 'Motivation | Inspiration| Success with Entrepreneur Coach Sam Crowley', 'Business', 'Active'),
#  ('Haviva Bradley', 'Bangladesh', 32883, 'G?©osciences et environnement', 'Education', 'Active'),
#  ('Haviva Bradley', 'Bangladesh', 32883, 'My Hard Drive Died - Podnutz', 'Technology/Software How-To', 'Active'),
#  ('Oscar Santiago', 'Belize', 77878, "Steven Redant's Podcast", 'Music', 'Active'),
#  ('Kareem Bartlett', 'Belize', 76639, '#NAME?', 'News & Politics', 'Active'),
#  ('Oscar Santiago', 'Belize', 77878, 'Emphasis', 'Public Radio', 'Active'),
#  ('Kareem Bartlett', 'Belize', 76639, 'Ezra', 'Religion & Spirituality', 'Active'),
#  ('Kareem Bartlett', 'Belize', 76639, 'The Science Hour', 'Technology', 'Active'),
#  ('Hannah Bird', 'Bolivia', 46965, 'Juicy Scoop with Heather McDonald', 'Comedy', 'Active'),
#  ('Hannah Bird', 'Bolivia', 46965, 'How I Met Your Mother', 'TV & Film', 'Active'),
#  ('Arsenio Fowler', 'Botswana', 22824, 'Embodied Awareness Podcast', 'Religion & Spirituality', 'Active'),
#  ('Celeste Mann', 'Burkina Faso', 13058, 'Music Mondays with Chris Millz (Outside The Boom Box)', 'Music', 'Active'),
#  ('Kyra Whitney', 'Cameroon', 83562, 'YoPro Wealth: Take Control of Your Finances. Make More Money. Live Wealthy.', 'Business', 'Active'),
#  ('Kyra Whitney', 'Cameroon', 12341, "What's The Point", 'Society & Culture', 'Active'),
#  ('Kyra Whitney', 'Cameroon', 24672, 'Abraham Lincoln: Vampire Hunter: Behind-the-Scenes', 'TV & Film', 'Active'),
#  ('Keiko Daugherty', 'Canada', 71265, 'Airsoftology - Airsoft Radio', 'Games & Hobbies', 'Active'),
#  ('Keiko Daugherty', 'Canada', 71265, 'Alexey Romeo pres. New Mashups', 'Music', 'Active'),
#  ('Keiko Daugherty', 'Canada', 71265, 'Heritage  Baptist Church in Opelika, Alabama', 'Religion & Spirituality', 'Active'),
#  ('Noah Hampton', 'China', 40303, 'Breakthrough with Rod Parsley AUDIO Podcast', 'Religion & Spirituality', 'Active'),
#  ('Noah Hampton', 'China', 40023, 'Project: Shadow', 'TV & Film', 'Active'),
#  ('Yardley Mccray', 'Colombia', 28241, '', '', 'Active'),
#  ('Yardley Mccray', 'Colombia', 28241, 'More Than Right Podcast', 'News & Politics', 'Active'),
#  ('Yardley Mccray', 'Colombia', 28471, '', 'Sports & Recreation/Professional', 'Active'),
#  ('Stone Higgins', 'Comoros', 45116, 'The University of Chicago Law School Faculty Podcast', 'Education', 'Active'),
#  ('Stone Higgins', 'Comoros', 34116, 'Friendship Bible Church', 'Religion & Spirituality', 'Active'),
#  ('Stone Higgins', 'Comoros', 11266, 'Home Theater Geeks (MP3)', 'Technology', 'Active'),
#  ('Gretchen Parks', 'Cook Islands', 28750, 'Tumble Science Podcast for Kids', 'Kids & Family', 'Active'),
#  ('Gretchen Parks', 'Cook Islands', 28770, 'Honey Glow: MLP Songs', 'Music', 'Active'),
#  ('Gretchen Parks', 'Cook Islands', 28750, 'Andrew Wommack TV Podcast (iPod Video)', 'Religion & Spirituality', 'Active'),
#  ('Donovan Duncan', 'Costa Rica', 65244, 'Radio Drama Revival', 'Arts', 'Active'),
#  ('Flynn Ferguson', 'Costa Rica', 40231, 'Coffee Ramblings', 'Comedy', 'Active'),
#  ('Donovan Duncan', 'Costa Rica', 67544, 'One Minute German', 'Education/Language Courses', 'Active'),
#  ('Donovan Duncan', 'Costa Rica', 65344, 'Simply Pets Radio (formerly Your Pets My Dogs) - on Pet Life Radio (PetLifeRadio.com)', 'Kids & Family', 'Active'),
#  ('Flynn Ferguson', 'Costa Rica', 40631, 'The Terrible Business of Salmon & Dusk', 'Magical Realism', 'Active'),
#  ('Flynn Ferguson', 'Costa Rica', 40321, 'The Trail Went Cold', 'News & Politics', 'Active'),
#  ('Salvador Nieves', 'Croatia', 54686, 'Sundance Film Festival: Meet The Artists', 'TV & Film', 'Active'),
#  ('Beverly Wolf', 'Cyprus', 79710, 'The Cricket Show & Others', '', 'Inactive'),
#  ('Beverly Wolf', 'Cyprus', 79710, 'SopranoCast', 'Movies & Television', 'Active'),
#  ('Beverly Wolf', 'Cyprus', 79710, 'FanGraphs Baseball', 'Sports & Recreation', 'Active'),
#  ('Brooke Price', 'Czech Republic', 47974, 'The Vitality Coach Podcast with Nikki Fogden-Moore: Vitality |Bringing Business and Personal Vitality To Life', 'Health', 'Active'),
#  ('Brooke Price', 'Czech Republic', 47974, 'triple j: Music News', 'International', 'Active'),
#  ('Brooke Price', 'Czech Republic', 47974, 'The Golden Hammer', 'Technology', 'Active'),
#  ('Maryam Mcintosh', 'Denmark', 73979, 'Latest in Paleo', 'Health', 'Active'),
#  ('Pearl Watkins', 'Equatorial Guinea', 85607, 'Marvel Noise', 'Arts/Literature', 'Active'),
#  ('Pearl Watkins', 'Equatorial Guinea', 85600, 'Physics 50 example problems', 'Higher Education', 'Inactive'),
#  ('Pearl Watkins', 'Equatorial Guinea', 85607, 'sports 15SOF', 'Sports & Recreation', 'Active'),
#  ('Tyrone Pierce', 'Estonia', 28645, 'Poetry Off the Shelf', '', 'Active'),
#  ('Tyrone Pierce', 'Estonia', 28647, 'Secrets, Crimes & Audiotape', 'Arts', 'Active'),
#  ('Ralph Herrera', 'Faroe Islands', 66422, '2 Nerds, 1 Podcast', 'Comedy', 'Active'),
#  ('Ralph Herrera', 'Faroe Islands', 66242, 'Tumble Science Podcast for Kids', 'Kids & Family', 'Active'),
#  ('Ralph Herrera', 'Faroe Islands', 64622, 'Jake Sampson: Monster Hunter ¬ª Podcast Feed', 'podcasting', 'Active'),
#  ('Dai Sargent', 'Finland', 33268, 'Radio Drama Revival', 'Arts', 'Active'),
#  ('Dai Sargent', 'Finland', 33268, 'Insomnia Radio: Daily Dose MP3 Blog', 'Music', 'Active'),
#  ('Yen Downs', 'Finland', 26929, 'DRUMATIKA by Pablo Ceballos', 'Music', 'Active'),
#  ('Yen Downs', 'Finland', 26929, 'Reuters Enterprise', 'News & Politics', 'Active'),
#  ('Dai Sargent', 'Finland', 33268, 'Sex Talk with Curvy', 'Romance', 'Active'),
#  ('Wang Benjamin', 'French Guiana', 97499, 'Alan Watts Podcast', 'Society & Culture/Philosophy', 'Active'),
#  ('Gabriel Walters', 'French Guiana', 63366, 'BC Podcast', 'Technology', 'Active'),
#  ('Rebecca Klein', 'French Polynesia', 91485, 'Blue & Gold Illustrated: Notre Dame Football And Recruiting', 'Sports & Recreation:College & High School', 'Inactive'),
#  ('Rebecca Klein', 'French Polynesia', 12352, 'Mad About Movies', 'TV & Film', 'Active'),
#  ('Rinah Ballard', 'Gabon', 43388, "Peter and Omar's Arts and Culture Show", 'Arts', 'Active'),
#  ('Elliott Herring', 'Gabon', 45271, 'In My Mug', 'Arts', 'Inactive'),
#  ('Elliott Herring', 'Gabon', 45271, 'Totaljobs.com careers advice', 'Business', 'Active'),
#  ('Elliott Herring', 'Gabon', 45271, 'Business Today', 'Business', 'Active'),
#  ('Rinah Ballard', 'Gabon', 74388, 'Juicy Scoop with Heather McDonald', 'Comedy', 'Active'),
#  ('Audrey Hughes', 'Georgia', 92093, "The Writer's podcast", 'Business', 'Active'),
#  ('Audrey Hughes', 'Georgia', 93203, 'Vocabulario en Ingles Podcast', 'Education', 'Inactive'),
#  ('Audrey Hughes', 'Georgia', 29203, 'CBC Radio: Special Delivery', 'podcast', 'Active'),
#  ('Aurora Gutierrez', 'Ghana', 22013, 'LitListen Books', '', 'Active'),
#  ('Aurora Gutierrez', 'Ghana', 22013, 'The Literary Salon', 'Arts/Literature', 'Active'),
#  ('Aurora Gutierrez', 'Ghana', 22013, 'Old Radio Detective', 'Society & Culture', 'Active'),
#  ('James Compton', 'Guam', 83020, 'NutritionFacts.org', 'Health', 'Inactive'),
#  ('Selma Jensen', 'Guinea', 10381, 'MorningCoach.com: Personal Development | Lifestyle Design', 'Health', 'Active'),
#  ('August Mejia', 'Guinea-Bissau', 62536, '5 Minute Classroom Management Fixes Podcast', '', 'Active'),
#  ('August Mejia', 'Guinea-Bissau', 62536, 'Dispatches from CBC Radio', 'News & Politics', 'Active'),
#  ('Phyllis Bender', 'Haiti', 97164, 'The Robert Wenzel Show', 'News & Politics', 'Inactive'),
#  ('Reuben Strickland', 'Heard Island and Mcdonald Islands', 94668, 'Shop Talk Live - Fine Woodworking', 'Games & Hobbies', 'Active'),
#  ('Reuben Strickland', 'Heard Island and Mcdonald Islands', 94667, 'Everyday Companion PaniCast', 'Music', 'Active'),
#  ('Reuben Strickland', 'Heard Island and Mcdonald Islands', 94665, 'Violin Geek Podcast', 'Music', 'Inactive'),
#  ('Harrison Maddox', 'Hong Kong', 72517, 'PictureMonk Photography Podcast', 'Arts', 'Active'),
#  ('Harrison Maddox', 'Hong Kong', 72257, 'The Jack Blood Show ¬ª The Jack Blood Show', 'Government & Organizations', 'Inactive'),
#  ('Harrison Maddox', 'Hong Kong', 72357, 'North Coast Church', 'Religion & Spirituality/Christianity', 'Active'),
#  ('Vance Lyons', 'Hungary', 71965, 'Chimneysmoke by MORLEY, Christopher', 'Arts', 'Active'),
#  ('Vance Lyons', 'Hungary', 71969, 'I Love A Good Story Podcast', 'Arts', 'Active'),
#  ('Vance Lyons', 'Hungary', 71995, 'PROFIT', 'Music', 'Active'),
#  ('Mason Curtis', 'Iceland', 69780, 'E3C: The Passionate Entrepreneur', 'Business', 'Active'),
#  ('Mason Curtis', 'Iceland', 69710, 'NYT Op-Ed Podcast', 'News', 'Active'),
#  ('Gisela Blanchard', 'Iran', 55120, "2011 Kenneth Copeland Ministries' Events Video Podcast", None, 'Active'),
#  ('Gisela Blanchard', 'Iran', 75120, '', '', 'Active'),
#  ('Gisela Blanchard', 'Iran', 24562, 'New Music, New Thoughts: Measure for Measure', 'music', 'Active'),
#  ('Kennan Reid', 'Kazakhstan', 32360, '', '', 'Inactive'),
#  ('Kennan Reid', 'Kazakhstan', 32130, 'Making Film with', 'TV & Film', 'Inactive'),
#  ('Buckminster Bates', 'Kiribati', 12773, 'Town Square', '', 'Active'),
#  ('Buckminster Bates', 'Kiribati', 12773, 'Fixing Joe Season 3', 'Comedy', 'Active'),
#  ('Buckminster Bates', 'Kiribati', 12773, 'Crucible Radio', 'Games & Hobbies/Video Games', 'Active'),
#  ('Reuben Benson', 'Korea, North', 16456, 'AutoSuccess: The Podcast', 'Business', 'Active'),
#  ('Reuben Benson', 'Korea, North', 53635, 'Spice | Romantic Stories of Love | Sex Charged Audio Stories Podcast', 'Health', 'Active'),
#  ('Reuben Benson', 'Korea, North', 82754, 'triple j: Marc Fennell (That Movie Guy)', 'TV & Film', 'Inactive'),
#  ('Nathaniel Ashley', 'Laos', 12340, 'Langsam gesprochene Nachrichten | Deutsch lernen | Deutsche Welle', 'Education', 'Inactive'),
#  ('Nathaniel Ashley', 'Laos', 12348, 'GSMC Baseball Podcast', 'Sports & Recreation', 'Active'),
#  ('Sawyer Brock', 'Liberia', 45860, 'Word Shots, the Podcast', 'Education', 'Active'),
#  ('Sawyer Brock', 'Liberia', 45830, 'Console Nerds - A Video Podcast', 'Games & Hobbies/Video Games', 'Active'),
#  ('Lacey Vargas', 'Lithuania', 32696, '2 Pages Of Mystery Podcast', 'Arts', 'Active'),
#  ('Lacey Vargas', 'Lithuania', 32696, 'Stoneface and Terminal Reflected Broadcast', 'Music', 'Active'),
#  ('Lacey Vargas', 'Lithuania', 32696, 'In Between Sundays ‚Äì A podcast for young adults.', 'Religion & Spirituality', 'Active'),
#  ('Portia Baxter', 'Luxembourg', 37373, 'Gilles Peterson', 'Music', 'Active'),
#  ('Portia Baxter', 'Luxembourg', 23471, "KCPT's Ruckus Podcast", 'News & Politics', 'Active'),
#  ('Portia Baxter', 'Luxembourg', 24625, 'On the Origin of Species by Means of Natural Selection by Charles Darwin', 'Sports & Recreation', 'Active'),
#  ('Colby Horton', 'Macao', 30614, 'ROOM84 PODCAST', 'Music', 'Active'),
#  ('Colby Horton', 'Macao', 30614, '848 Podcast', 'News & Politics', 'Active'),
#  ('Jeanette Petty', 'Mali', 35397, '', '', 'Active'),
#  ('Jeanette Petty', 'Mali', 35397, 'The Happiness Podcast', 'Health', 'Active'),
#  ('Jeanette Petty', 'Mali', 35397, 'SciFi Tech Talk', 'TV & Film', 'Active'),
#  ('Sean Cohen', 'Malta', 17283, 'Nuts & Bolts of Christian Life', 'Religion & Spirituality', 'Active'),
#  ('Brett Diaz', 'Martinique', 72399, "Stories Podcast - A Free Children's Story Podcast for Bedtime, Car Rides, and Kids of All Ages!", 'Kids & Family', 'Inactive'),
#  ('Brett Diaz', 'Martinique', 72399, 'Dr. Steven J. Lawson - SermonAudio.com', 'Religion & Spirituality', 'Active'),
#  ('Brett Diaz', 'Martinique', 72399, 'SourceTrunk', 'Technology', 'Active'),
#  ('Norman Petty', 'Mayotte', 87477, 'Reality Life with Kate Casey', 'Comedy', 'Active'),
#  ('Norman Petty', 'Mayotte', 82747, 'Tauren Think Tank: The Podcast About the Blizzard Gamer Behind the Keyboard', 'Games & Hobbies', 'Active'),
#  ('Norman Petty', 'Mayotte', 87647, 'SHREDZ Workout Mix', 'Music', 'Active'),
#  ('Tate Crane', 'Moldova', 81750, 'Out of the Box', 'Arts', 'Active'),
#  ('India Nelson', 'Moldova', 23793, 'GRDC - Driving Agronomy Podcasts', 'Business', 'Active'),
#  ('Tate Crane', 'Moldova', 81270, 'Superintendent Radio Network', 'Business', 'Active'),
#  ('India Nelson', 'Moldova', 27816, 'The Zippy & Ghandi Show', 'Comedy', 'Active'),
#  ('Dawn Noel', 'Moldova', 35856, 'Radio Detective Story Hour', 'Kids & Family', 'Active'),
#  ('Tate Crane', 'Moldova', 81270, 'Special Defects Podcast', 'Music', 'Inactive'),
#  ('Dawn Noel', 'Moldova', 35856, 'TransAdvocate', 'Society & Culture', 'Active'),
#  ('India Nelson', 'Moldova', 99831, 'iPhone 101', 'Technology/Gadgets', 'Active'),
#  ('Dawn Noel', 'Moldova', 35856, 'The Walking Dead ‚ÄòCast', 'TV & Film', 'Active'),
#  ('Jonas Freeman', 'Montenegro', 17157, 'Soundcheck from WNYC', 'Music', 'Active'),
#  ('Allegra Howell', 'Nepal', 64246, 'Crossing Continents', '', 'Active'),
#  ('Allegra Howell', 'Nepal', 64246, 'The Adventures in Odyssey Blog', 'Official Podcast', 'Active'),
#  ('Allegra Howell', 'Nepal', 64246, 'The Vanished Podcast', 'Society & Culture', 'Active'),
#  ('Bevis Mercado', 'Netherlands', 25621, 'Christmas Carol (version 08 dramatic reading), A by DICKENS, Charles', 'Arts', 'Active'),
#  ('Randall Hess', 'Netherlands', 12459, 'A Voice for Men', 'Blogs', 'Active'),
#  ('Randall Hess', 'Netherlands', 61259, 'Stories to Read, Words to Know, Level C', 'Education', 'Active'),
#  ('Bevis Mercado', 'Netherlands', 25621, 'Podcast ‚Äì Spellburn', 'Games & Hobbies/Other Games', 'Active'),
#  ('Randall Hess', 'Netherlands', 12259, 'Super Dad Show ¬ª Podcast', 'Kids & Family', 'Active'),
#  ('Bevis Mercado', 'Netherlands', 25621, 'Calvary Chapel Central Maine - Ken Graves', 'Religion & Spirituality', 'Active'),
#  ('Griffin Wood', 'New Zealand', 12349, 'Mission Sermon Podcasts', 'Religion & Spirituality', 'Active'),
#  ('Lee Gross', 'Niger', 92822, 'This Girl Means Business', 'Business', 'Active'),
#  ('Kirsten Mills', 'Niue', 41709, 'The Brutal Backhand', 'Music', 'Active'),
#  ('Kirsten Mills', 'Niue', 41709, 'Sword and Scale', 'Science & Medicine', 'Active'),
#  ('Kirsten Mills', 'Niue', 41709, 'Jane Austen Season Audiobooks with ITV1 & Classic FM', 'TV & Film', 'Active'),
#  ('Rhona Booth', 'Norway', 39272, 'Out of the Blue', 'TV & Film', 'Active'),
#  ('Armand Kelly', 'Oman', 96679, 'Rob Hayes', 'Business', 'Active'),
#  ('Armand Kelly', 'Oman', 96699, 'Virtual AD/HD Conference‚Ñ¢ Podcast 2010', 'Health & Fitness', 'Active'),
#  ('Armand Kelly', 'Oman', 96699, 'Nightlife', 'Society & Culture', 'Active'),
#  ('Moses Blake', 'Palau', 86842, 'Dudes Talking About Chicks', 'Health', 'Active'),
#  ('Moses Blake', 'Palau', 78682, 'No Entries', 'Music', 'Active'),
#  ('Jasper Mayer', 'Palau', 60891, 'Truth & Justice with Bob Ruff', 'News & Politics', 'Active'),
#  ('Jasper Mayer', 'Palau', 76091, 'Word of Mouth from NHPR', 'News & Politics', 'Active'),
#  ('Moses Blake', 'Palau', 85682, 'Actors Talk - Come Inside The Acting Business', 'TV & Film', 'Inactive'),
#  ('Ulric Guerra', 'Palestine, State of', 55087, 'Food Fridays (The Leonard Lopate Show)', '', 'Active'),
#  ('Ulric Guerra', 'Palestine, State of', 55087, 'Tumble Science Podcast for Kids', 'Kids & Family', 'Active'),
#  ('Ulric Guerra', 'Palestine, State of', 55087, 'BacterioFiles', 'Science & Medicine/Natural Sciences', 'Active'),
#  ('Elton Lang', 'Philippines', 76881, 'Carmody Central Podcast', 'Comedy', 'Active'),
#  ('Elton Lang', 'Philippines', 76881, 'The Vanished Podcast', 'Society & Culture', 'Active'),
#  ('Hilary Mckenzie', 'Portugal', 32924, 'Reality Life with Kate Casey', 'Comedy', 'Active'),
#  ('Adrian Wells', 'Portugal', 11134, "Heatherly and Julie's Fantasy Bedtime Hour", 'Comedy', 'Active'),
#  ('Adrian Wells', 'Portugal', 11613, 'Photoshop Creative Podcasts', 'Design', 'Active'),
#  ('Adrian Wells', 'Portugal', 31113, 'Old Republic Radio', 'Games & Hobbies', 'Active'),
#  ('Hilary Mckenzie', 'Portugal', 32924, 'Voi siete qui', 'News & Politics', 'Active'),
#  ('Hilary Mckenzie', 'Portugal', 32924, 'Poptopia', 'TV & Film', 'Active'),
#  ('Scarlett Dudley', 'Qatar', 99946, '7th Son: Book Two - Deceit (The Beta Version)', 'Science Fiction', 'Active'),
#  ('Scarlett Dudley', 'Qatar', 99946, "C.M. Mayo's Podcast (Marfa Mondays & More)", 'Society & Culture', 'Active'),
#  ('Scarlett Dudley', 'Qatar', 21372, 'Footballistically Arsenal Excerpts', 'Sports & Recreation', 'Inactive'),
#  ('Clayton Mccoy', 'Saudi Arabia', 63504, 'Canadian Business Podcast', 'Business', 'Active'),
#  ('Clayton Mccoy', 'Saudi Arabia', 65044, "ESV: M'Cheyne Reading Plan", 'Religion & Spirituality', 'Active'),
#  ('Clayton Mccoy', 'Saudi Arabia', 65024, 'Sword and Scale', 'Science & Medicine', 'Active'),
#  ('Deacon Bird', 'Serbia', 14293, 'The Franetic Podcast [ Electronica | Trance | Psy | Hard Dance ]', 'Music', 'Active'),
#  ('Deacon Bird', 'Serbia', 14993, '1LIVE Talk', 'Society & Culture', 'Active'),
#  ('Christine Hansen', 'Serbia', 32751, 'The JetsInsider Radio Show', 'Sports', 'Active'),
#  ('Christine Hansen', 'Serbia', 32751, 'Inside Sport', 'Sports & Recreation', 'Active'),
#  ('Christine Hansen', 'Serbia', 32051, 'American Speedway News', 'sports, speedway, racing, cycles', 'Active'),
#  ('Sigourney Alvarado', 'Slovakia', 61606, 'the cricket show', 'Sports & Recreation', 'Active'),
#  ('Penelope Cabrera', 'Slovenia', 44332, 'Reality Life with Kate Casey', 'Comedy', 'Active'),
#  ('Penelope Cabrera', 'Slovenia', 44432, 'Solomonster Sounds Off', 'Sports & Recreation', 'Active'),
#  ('Penelope Cabrera', 'Slovenia', 44432, 'Wrestling Podcast About Nothing', 'Sports & Recreation', 'Active'),
#  ('Quynn Knapp', 'Somalia', 40409, 'Manchester Business', 'Business', 'Active'),
#  ('Quynn Knapp', 'Somalia', 40409, 'Casually Hardcore', 'Games & Hobbies', 'Active'),
#  ('Quynn Knapp', 'Somalia', 40409, 'New Free Music', 'Music', 'Active'),
#  ('Michelle Joseph', 'South Georgia and The South Sandwich Islands', 89396, 'Nerds For Hire Podcast', 'Business', 'Active'),
#  ('Michelle Joseph', 'South Georgia and The South Sandwich Islands', 89396, 'The Incurable Allure of Carrots', 'podcast', 'Inactive'),
#  ('Michelle Joseph', 'South Georgia and The South Sandwich Islands', 89396, 'Orkun ?áolakoƒülu ‚Äì yazƒ±hane', 'Sports & Recreation', 'Active'),
#  ('Prescott Pruitt', 'Spain', 99863, "PETA's Podcast", 'Government & Organizations', 'Active'),
#  ('Sylvia Craig', 'Suriname', 42348, 'Secrets, Crimes & Audiotape', 'Arts', 'Active'),
#  ('Sylvia Craig', 'Suriname', 26254, 'SoulNudge.Me', 'Religion & Spirituality', 'Active'),
#  ('Sylvia Craig', 'Suriname', 43248, "The Catholic Guy Show's Podcast", 'Religion & Spirituality/Christianity', 'Active'),
#  ('Olympia Lowe', 'Svalbard and Jan Mayen Islands', 25627, 'Cross of Christ Church - Audio', 'Religion & Spirituality', 'Active'),
#  ('Cedric Nieves', 'Syria', 87631, 'Religionen - Deutschlandradio Kultur', 'Info', 'Active'),
#  ('Cedric Nieves', 'Syria', 87631, 'Hoy por Hoy', 'News & Politics', 'Active'),
#  ('Cedric Nieves', 'Syria', 87631, "RebelGrove's Podcast Channel", 'Sports', 'Active'),
#  ('Jin Solomon', 'Syria', 63754, 'Adventures in Fly Fishing with Fly Fish Ohio', 'Sports & Recreation', 'Active'),
#  ('Channing Jacobson', 'Tanzania', 88150, 'Audiophile', 'Arts/Design', 'Active'),
#  ('Channing Jacobson', 'Tanzania', 88150, 'Logos Radio Network ¬ª Truth Exposed Radio', 'News & Politics', 'Active'),
#  ('Dakota Cervantes', 'Timor-Leste', 38086, 'Pub Quiz Podcast', 'Arts & Entertainment', 'Active'),
#  ('Dakota Cervantes', 'Timor-Leste', 38086, 'Paurav Shukla on marketing management', 'Business', 'Active'),
#  ('Dakota Cervantes', 'Timor-Leste', 78086, 'Mil palabras en ingles', 'Education', 'Active'),
#  ('Portia Christensen', 'Togo', 79438, 'Dental Practice 911 Radio', 'Business', 'Active'),
#  ('Tiger Carter', 'Tokelau', 86406, 'Increase My Small Business', 'Business', 'Inactive'),
#  ('Tiger Carter', 'Tokelau', 86406, "Stories Podcast - A Free Children's Story Podcast for Bedtime, Car Rides, and Kids of All Ages!", 'Kids & Family', 'Inactive'),
#  ('Tiger Carter', 'Tokelau', 86346, 'Tommy Trash - Trashed Podcast', 'Music', 'Inactive'),
#  ('Cedric Lott', 'Tonga', 13261, 'Reality Life with Kate Casey', 'Comedy', 'Active'),
#  ('Cedric Lott', 'Tonga', 27245, 'Thee Alex on alonetone.com', 'Music', 'Active'),
#  ('Cedric Lott', 'Tonga', 25682, 'The Vanished Podcast', 'Society & Culture', 'Active'),
#  ('Lucy Greer', 'Turkey', 73217, 'BeGainful', 'Business', 'Active'),
#  ('Lucy Greer', 'Turkey', 73137, 'The Dash', 'Business', 'Active'),
#  ('Lucy Greer', 'Turkey', 73177, 'Studio Guyz Movement Podcast', 'Music', 'Active'),
#  ('Shelley Norman', 'Tuvalu', 73540, 'Raise Your Hand Say Yes with Tiffany Han', 'Arts', 'Active'),
#  ('Cole Waller', 'Tuvalu', 24382, 'No Meat Athlete Radio', 'Health', 'Active'),
#  ('Cole Waller', 'Tuvalu', 25472, 'Jalan-Jalan Cuap-Cuap', 'Society & Culture', 'Active'),
#  ('Shelley Norman', 'Tuvalu', 73460, 'WIRED News ‚Äì Spoken Edition', 'Technology', 'Active'),
#  ('Cole Waller', 'Tuvalu', 13246, 'SEO Rank Warriors ¬ª Blog', 'Technology', 'Active'),
#  ('Sybil Guy', 'Ukraine', 51489, 'Alcoholics Anonymous\r1st Edition', '', 'Active'),
#  ('Sybil Guy', 'Ukraine', 51489, 'The C.O.W.S.', 'Education', 'Active'),
#  ('Sybil Guy', 'Ukraine', 51409, 'Burpee Home Gardens Tip of The Week Podcast', 'Health/Fitness & Nutrition', 'Active'),
#  ('Isabelle Whitehead', 'Wallis and Futuna', 37839, '', '', 'Active'),
#  ('Isabelle Whitehead', 'Wallis and Futuna', 37839, 'Podcast ‚Äì John vs Patrick', 'Comedy', 'Active'),
#  ('Isabelle Whitehead', 'Wallis and Futuna', 37839, 'The Echo & Ken Show: Small Town News & Humor', 'News & Politics', 'Active')]

# %%
# %%sql
# SELECT CONCAT(pl.first_name, ' ', pl.last_name) AS listener_name, pl.country, pl.zip_code, ps.title AS podcast_title, ps.author, ps.category AS genre,
#             CASE
#                 WHEN pl.user_activity = 0 THEN 'Active'
#                 WHEN pl.user_activity = 1 THEN 'Inactive'
#             END AS listener_status
# FROM `podcast shows` ps
# JOIN `podcast listeners` pl
#     ON ps.id = pl.id
# WHERE ps.author LIKE '%Wondery%'
# ORDER BY pl.country;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 21 rows affected.
# [('Hannah Bird', 'Bolivia', 46965, 'Juicy Scoop with Heather McDonald', 'Heather McDonald / Wondery', 'Comedy', 'Active'),
#  ('Gretchen Parks', 'Cook Islands', 28750, 'Tumble Science Podcast for Kids', 'Tumble Media / Wondery', 'Kids & Family', 'Active'),
#  ('Donovan Duncan', 'Costa Rica', 65244, 'Radio Drama Revival', 'Radio Drama Revival / Wondery', 'Arts', 'Active'),
#  ('Tyrone Pierce', 'Estonia', 28647, 'Secrets, Crimes & Audiotape', 'Wondery', 'Arts', 'Active'),
#  ('Ralph Herrera', 'Faroe Islands', 66242, 'Tumble Science Podcast for Kids', 'Tumble Media / Wondery', 'Kids & Family', 'Active'),
#  ('Dai Sargent', 'Finland', 33268, 'Radio Drama Revival', 'Radio Drama Revival / Wondery', 'Arts', 'Active'),
#  ('Rebecca Klein', 'French Polynesia', 12352, 'Mad About Movies', 'Kent Garrison, Richard Bardon, Brian Gill / Wondery', 'TV & Film', 'Active'),
#  ('Rinah Ballard', 'Gabon', 74388, 'Juicy Scoop with Heather McDonald', 'Heather McDonald / Wondery', 'Comedy', 'Active'),
#  ('Brett Diaz', 'Martinique', 72399, "Stories Podcast - A Free Children's Story Podcast for Bedtime, Car Rides, and Kids of All Ages!", 'Stories Podcast / Wondery', 'Kids & Family', 'Inactive'),
#  ('Norman Petty', 'Mayotte', 87477, 'Reality Life with Kate Casey', 'Kate Casey / Wondery', 'Comedy', 'Active'),
#  ('Allegra Howell', 'Nepal', 64246, 'The Vanished Podcast', 'The Vanished Podcast / Wondery', 'Society & Culture', 'Active'),
#  ('Kirsten Mills', 'Niue', 41709, 'Sword and Scale', 'True Crime Media | Incongruity | Wondery', 'Science & Medicine', 'Active'),
#  ('Ulric Guerra', 'Palestine, State of', 55087, 'Tumble Science Podcast for Kids', 'Tumble Media / Wondery', 'Kids & Family', 'Active'),
#  ('Elton Lang', 'Philippines', 76881, 'The Vanished Podcast', 'The Vanished Podcast / Wondery', 'Society & Culture', 'Active'),
#  ('Hilary Mckenzie', 'Portugal', 32924, 'Reality Life with Kate Casey', 'Kate Casey / Wondery', 'Comedy', 'Active'),
#  ('Clayton Mccoy', 'Saudi Arabia', 65024, 'Sword and Scale', 'True Crime Media | Incongruity | Wondery', 'Science & Medicine', 'Active'),
#  ('Penelope Cabrera', 'Slovenia', 44332, 'Reality Life with Kate Casey', 'Kate Casey / Wondery', 'Comedy', 'Active'),
#  ('Sylvia Craig', 'Suriname', 42348, 'Secrets, Crimes & Audiotape', 'Wondery', 'Arts', 'Active'),
#  ('Tiger Carter', 'Tokelau', 86406, "Stories Podcast - A Free Children's Story Podcast for Bedtime, Car Rides, and Kids of All Ages!", 'Stories Podcast / Wondery', 'Kids & Family', 'Inactive'),
#  ('Cedric Lott', 'Tonga', 13261, 'Reality Life with Kate Casey', 'Kate Casey / Wondery', 'Comedy', 'Active'),
#  ('Cedric Lott', 'Tonga', 25682, 'The Vanished Podcast', 'The Vanished Podcast / Wondery', 'Society & Culture', 'Active')]

# %% [markdown]
# ### Business Question #1
# Recommendation: Based on the results, Wondery should include more business, technology, religion and sports based podcasts. Wondery has many podcasts in Comedy, Society&Culture and Arts, however, if they want to expand globally, they need to expand their repertoire. Listener tastes vary from person to person, however, Wondery could get a higher listener base if they added more genres of podcasts.

# %% [markdown]
# ### Business Question #1
# ### Trigger

# %%
# %%sql
# CREATE TABLE Podcast_User_Preference (
# listener_name VARCHAR(255),
# country VARCHAR(255),
# zip_code INT(11),
# podcast_title VARCHAR(255),
# genre VARCHAR(255),
# listener_status VARCHAR(255)
# );
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# (MySQLdb._exceptions.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ')' at line 8")
# [SQL: CREATE TABLE Podcast_User_Preference (
# listener_name VARCHAR(255),
# country VARCHAR(255),
# zip_code INT(11),
# podcast_title VARCHAR(255),
# genre VARCHAR(255),
# listener_status VARCHAR(255),
# );]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# DELIMITER $$
# CREATE TRIGGER Podcast_User_Preferences_Update
#     AFTER UPDATE ON Podcast_User_Preference
#     FOR EACH ROW
# BEGIN
#     INSERT INTO User_Preference_Log(listener_name, country, zip_code, podcast_title, genre, listener_status)
#     VALUES
#     (OLD.listener_name(), OLD.country, OLD.zip_code, OLD.podcast_title, OLD.genre, OLD.listener_status);
# END$$
# DELIMITER ;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# (MySQLdb._exceptions.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'DELIMITER $$\nCREATE TRIGGER Podcast_User_Preferences_Update\n    AFTER UPDATE ON ' at line 1")
# [SQL: DELIMITER $$
# CREATE TRIGGER Podcast_User_Preferences_Update
#     AFTER UPDATE ON Podcast_User_Preference
#     FOR EACH ROW
# BEGIN
#     INSERT INTO User_Preference_Log(listener_name, country, zip_code, podcast_title, genre, listener_status)
#     VALUES
#     (OLD.listener_name(), OLD.country, OLD.zip_code, OLD.podcast_title, OLD.genre, OLD.listener_status);
# END$$
# DELIMITER ;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# ### Business Question #2
# Question: What types of businesses advertiser through podcasts?
#
# Business Justification: This query helps the Wondery company better understand what types of businesses are advertising in podcasts. The analyst can look at the query and see which types_of_businesses are advertising for which genre of podcasts. From this, Wondery can find current businesses that should advertise on their shows. They can also use this data to find similar companies to advertise on their show.
#
# SQL Features Used: Subquery, GROUP BY, Aggregate Functions, VIEW

# %%
# %%sql
# CREATE OR REPLACE VIEW podcast_advertiser_information AS
#     SELECT ps.title AS podcast_title, ps.category AS genre, ps.language, ps.advertiser_id, pa.company AS advertiser, pa.type_of_business AS advertiser_business, pa.email,
#     (
#         SELECT COUNT(advertiser_id)
#         FROM `podcast shows`
#         WHERE advertiser_id = ps.advertiser_id
#     ) AS count_of_advertisers
#     FROM `podcast shows` ps
#     JOIN `podcast advertisers` pa
#         ON ps.id = pa.id
#     GROUP BY pa.advertiser_id;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM podcast_advertiser_information;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# 30 rows affected.
# [('180 Nutrition -The Health Sessions.', 'Health', 'en', 10, 'USA Today', 'entertainment', 'amet.dapibus@faucibusorciluctus.net', 1325),
#  ('180 Nutrition -The Health Sessions.', 'Health', 'en', 10, 'StatSocial', 'technology', 'ss@statsocial.com', 1325),
#  ('2 Dudes and a NES', 'Games & Hobbies', 'en-us', 6, 'ZipRecruiter', 'employment marketplace', 'vestibulum@facilisiSedneque.ca', 1329),
#  ("2010 Kenneth Copeland Ministries' Events Audio Podcast", None, 'en-us', 22, 'Geico', 'insurance', 'Duis.a@velnisl.edu', 1235),
#  ('2Controllers1Sofa', 'Games & Hobbies', 'en', 13, 'Robinhood', 'finanicial services', 'nibh.Quisque.nonummy@miacmattis.ca', 1271),
#  ('3 Wine Guys', 'Arts', 'en-us', 23, 'Indeed', 'employment marketplace', 'id.ante@enimconsequat.co.uk', 1297),
#  ('3 Wine Guys', 'Arts', 'en-us', 23, 'Squarespace', 'internet', 'magna@anteMaecenasmi.edu', 1297),
#  ("30 sec. inside a guy's brain", 'Health', 'en-us', 13, 'Quip', 'health care', 'lacus.Etiam.bibendum@Vivamussit.edu', 1271),
#  ('360 Entrepreneur Podcast with Yann ilunga', 'Business', 'en', 24, 'Zenni Optical', 'optical', 'ac.metus@eleifendnondapibus.net', 1360),
#  ('360documentaries - Full program podcast', 'Society & Culture', 'en-au', 27, 'Madison Reed', 'beauty', 'ridiculus.mus@nasceturridiculusmus.co.uk', 1277),
#  ("5times' Podcast", 'Sports & Recreation', 'en-us', 21, 'Audible', 'entertainment', 'mus.Proin@parturientmontesnascetur.edu', 1334),
#  ("5times' Podcast", 'Sports & Recreation', 'en-us', 21, 'Procter&Gamble', 'consumer goods', 'et@Duisdignissimtempor.ca', 1334),
#  ("5times' Podcast", 'Sports & Recreation', 'en-us', 21, 'Adobe', 'technology', 'adobe@adobe.net', 1334),
#  ('60 Cycle Hum: The Guitar Podcast!', 'Music', 'en', 8, 'Casper', 'mattress', 'non@nonmassa.edu', 1259),
#  ('60 Second Mac', 'Technology', 'en-us', 10, 'Skillshare', 'e-learning', 'Cras.lorem@adipiscingfringilla.edu', 1325),
#  ('60 Second Mac', 'Technology', 'en-us', 10, 'MakeAWish', 'nonprofit', 'tincidunt@risusDonecnibh.org', 1325),
#  ('6000 Chicken Fajitas', 'Comedy', 'en', 7, 'HBO', 'entertainment', 'Morbi.sit@mi.ca', 1349),
#  ('6000 Chicken Fajitas', 'Comedy', 'en', 7, 'Allstate', 'insurance', 'mauris.sit.amet@lacus.ca', 1349),
#  ('Calvary Chapel Central Maine - Ken Graves', 'Religion & Spirituality', 'en-us', 20, 'Toyota', 'vehicle', 'at.velit@necdiamDuis.com', 1258),
#  ("ESV: M'Cheyne Reading Plan", 'Religion & Spirituality', 'en-us', 25, 'FedEx', 'delivery', 'semper.rutrum@elit.edu', 1321),
#  ('I Love A Good Story Podcast', 'Arts', 'en-us', 21, 'Care/of', 'health care', 'eu.tellus.eu@egetmassa.co.uk', 1334),
#  ('Photoshop Creative Podcasts', 'Design', 'en-gb', 30, 'Prudential', 'finanicial services', 'Ut@ullamcorper.co.uk', 653),
#  ('Photoshop Creative Podcasts', 'Design', 'en-gb', 30, 'Banana Republic', 'apparel', 'banana@republic.com', 653),
#  ('Religionen - Deutschlandradio Kultur', 'Info', 'de-de', 18, 'ThirdLove', 'apparel', 'eleifend@libero.org', 1308),
#  ('SEO Rank Warriors ¬ª Blog', 'Technology', 'en-us', 15, 'Tmobile', 'telecommunications', 'lorem.ut@netuset.ca', 1307),
#  ('SEO Rank Warriors ¬ª Blog', 'Technology', 'en-us', 15, 'Airbnb', 'travel', 'customer@airbnb.com', 1307),
#  ('Spice | Romantic Stories of Love | Sex Charged Audio Stories Podcast', 'Health', 'en', 16, 'Stamps.com', 'delivery', 'ut.erat@mattisIntegereu.ca', 1307),
#  ('The Cricket Show & Others', '', 'en-us', 17, 'Progressive', 'insurance', 'molestie@Pellentesque.com', 1284),
#  ('The University of Chicago Law School Faculty Podcast', 'Education', 'en', 13, 'Dunkin Donuts', 'fast food', 'luctus.ut@Nullam.co.uk', 1271),
#  ('WIRED News ‚Äì Spoken Edition', 'Technology', 'en', 27, 'SimpliSafe', 'security', 'a@ligula.net', 1277)]

# %% [markdown]
# ### Business Question #2
# Recommendation: From the current genres of podcasts at Wondery, I would recommend they look into getting Care/of, HBO, Indeed and Squarespace because these companies have advertisements in podcasts with genres in art, comedy, and health. From there, they should look into similar companies with business in health care, entertainment, and technology to advertise on their podcasts that do not currently advertise in this space. Time Warner Inc, and NBC Universal could be good companies to start with.

# %% [markdown]
# ### Business Question #2
# ### Stored Procedure

# %%
# %%sql
# DELIMITER $$
# DROP PROCEDURE IF EXISTS getPodcastAdvertisersList$$
#
# CREATE PROCEDURE getPodcastAdvertisersList (inAdvertiserID INT, OUT outAdvertiserName VARCHAR(255))
# BEGIN
#     SET @advertiser_id := inAdvertiserID;
#
#     SELECT company INTO outAdvertiserName
#     FROM `podcast advertisers`
#     WHERE advertiser_id = @advertiser_id;
# END $$
# DELIMITER ;
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# (MySQLdb._exceptions.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'DELIMITER $$\nDROP PROCEDURE IF EXISTS getPodcastAdvertisersList$$\n\nCREATE PROCED' at line 1")
# [SQL: DELIMITER $$
# DROP PROCEDURE IF EXISTS getPodcastAdvertisersList$$
#
# CREATE PROCEDURE getPodcastAdvertisersList (inAdvertiserID INT, OUT outAdvertiserName VARCHAR(255))
# BEGIN
#     SET @advertiser_id := inAdvertiserID;
#
#     SELECT company INTO outAdvertiserName
#     FROM `podcast advertisers`
#     WHERE advertiser_id = @advertiser_id;
# END $$
# DELIMITER ;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# CALL getPodcastAdvertisersList(24);
# Out:
#  * mysql://admin:***@podcast-shows-db.cn69ibyjtgb1.us-east-2.rds.amazonaws.com/podcast_shows
# (MySQLdb._exceptions.OperationalError) (1305, 'PROCEDURE podcast_shows.getPodcastAdvertisersList does not exist')
# [SQL: CALL getPodcastAdvertisersList(24);]
# (Background on this error at: http://sqlalche.me/e/e3q8)
